# %% [markdown]
# (a) lst[0] = 3
# (b) lst[3] = 5
# (c) lst[x] = lst[2] = 1
# (d) lst[-x] = lst[-2] = 5
# (e) lst[x+1] = lst[3] = 5
# (f) lst[x] + 1 = 1 + 1 = 2
# (g) lst[lst[x]] = lst[1] = 0
# (h) lst[lst[lst[x]]] = lst[0] = 3
